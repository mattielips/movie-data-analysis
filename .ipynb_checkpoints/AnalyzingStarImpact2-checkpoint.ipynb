# %%
import numpy as np #linear algebra
import pandas as pd #data processing
# libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)


# Importing into dataframe

df_IMDB_MovieCatalog = pd.read_excel("df_IMDB_MovieCatalog.xlsx")
df_Movie_Financials = pd.read_excel("df_Movie_Financials.xlsx")
df_StarPlayersWith_Tconst = pd.read_excel("df_StarActors_With_nconst_tconst.xlsx")

# df_KnownFor = pd.read_excel ('./Prj_Data/ImdbScrapingData/TheNumbers/output/df_starsplayers_knownForMovies.xlsx', sheet_name='Export')
df_Stars = pd.read_excel ('df_StarActors_NoDups.xlsx', sheet_name='Export')

# %%
df_actors = df_Stars[df_Stars["Contribution"]=="Actor"][["Movies", "Average"]]
df_dir = df_Stars[df_Stars["Contribution"]=="Director"][["Movies", "Average"]]
df_ScrW = df_Stars[df_Stars["Contribution"]=="Writer"][["Movies", "Average"]]
df_prod = df_Stars[df_Stars["Contribution"]=="Producer"][["Movies", "Average"]]

# %%
# boxplot = sns.boxplot(data=df_Stars["Movies"])

# Boxplot Grouped by Categorical Variable

test = df_Stars[["Contribution", "Movies", "Average"]]

# boxplot = sns.boxplot(x=df_Stars["Contribution"], y="Movies", data=test)
boxplot = sns.boxplot(x=df_Stars["Contribution"], y="Average", data=test)

# boxplot = sns.boxplot(data=data)

boxplot.set(xlabel ="Job Function", ylabel='Average $ Generated Per Movie', title='Average Domestic Gross $ Generated Per Movie')
plt.ylim(0, None)
# plt.xlim(0, None)
# Out:
# (0.0, 782812767.95)

# %%
# boxplot = sns.boxplot(data=df_Stars["Movies"])

# Boxplot Grouped by Categorical Variable

test = df_Stars[["Contribution", "Movies", "Average"]]

boxplot = sns.boxplot(x=df_Stars["Contribution"], y="Movies", data=test)
# boxplot = sns.boxplot(x=df_Stars["Contribution"], y="Average", data=test)

# boxplot = sns.boxplot(data=data)

boxplot.set(xlabel ="Job Function", ylabel='Average # Of Movies', title='Average # Movies Roles')
plt.ylim(0, None)
# plt.xlim(0, None)
# Out:
# (0.0, 89.2)

# %%
g = sns.FacetGrid(test, col="Contribution", hue="Contribution");
g.map(sns.scatterplot, "Movies", "Average", alpha=.7);
g.add_legend();

plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0.0, 89.2)

# %%
sns.distplot(df_actors.Movies)
plt.ylim(0, None)
plt.xlim(0, 80)
# Out:
# (0.0, 80.0)

# %%
sns.distplot(df_actors.Average)
# plt.ylim(0, None)
# plt.xlim(0, 80)

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
plt.show()

# %%
# test = df_Stars["Contribution"]

# format_dict = {'25%':'${0:,.0f}', '50%':'${0:,.0f}'}
# monthly_sales.style.format(format_dict).hide_index()


test = df_Stars.groupby(["Contribution"])["Average"]
# test.describe().style.format({"max":'${0:,.0f}'})
test.describe().style.format('${0:,.0f}')
# test.head(1)
# .style.format({'C': str.upper})

# adf.head().style.format({"col1": "{:,.0f}", "col2": "{:,.0f}"}) (per
# Out:
# <style  type="text/css" >
# </style><table id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >Contribution</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8blevel0_row0" class="row_heading level0 row0" >Actor</th>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col0" class="data row0 col0" >$1,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col1" class="data row0 col1" >$67,039,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col2" class="data row0 col2" >$71,017,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col3" class="data row0 col3" >$4,481,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col4" class="data row0 col4" >$25,944,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col5" class="data row0 col5" >$45,279,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col6" class="data row0 col6" >$82,266,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow0_col7" class="data row0 col7" >$745,749,000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8blevel0_row1" class="row_heading level0 row1" >Director</th>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col0" class="data row1 col0" >$0</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col1" class="data row1 col1" >$80,163,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col2" class="data row1 col2" >$68,771,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col3" class="data row1 col3" >$9,080,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col4" class="data row1 col4" >$34,443,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col5" class="data row1 col5" >$57,294,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col6" class="data row1 col6" >$100,228,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow1_col7" class="data row1 col7" >$439,056,000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8blevel0_row2" class="row_heading level0 row2" >Producer</th>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col0" class="data row2 col0" >$0</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col1" class="data row2 col1" >$92,337,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col2" class="data row2 col2" >$78,866,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col3" class="data row2 col3" >$9,491,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col4" class="data row2 col4" >$45,003,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col5" class="data row2 col5" >$68,135,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col6" class="data row2 col6" >$113,936,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow2_col7" class="data row2 col7" >$608,582,000</td>
#             </tr>
#             <tr>
#                         <th id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8blevel0_row3" class="row_heading level0 row3" >Writer</th>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col0" class="data row3 col0" >$0</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col1" class="data row3 col1" >$110,060,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col2" class="data row3 col2" >$65,247,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col3" class="data row3 col3" >$18,123,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col4" class="data row3 col4" >$61,564,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col5" class="data row3 col5" >$88,026,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col6" class="data row3 col6" >$138,117,000</td>
#                         <td id="T_6c508ac8_0676_11eb_a9b3_482ae352cd8brow3_col7" class="data row3 col7" >$333,172,000</td>
#             </tr>
#     </tbody></table>

# %%
# test = df_Stars["Contribution"]

# format_dict = {'25%':'${0:,.0f}', '50%':'${0:,.0f}'}
# monthly_sales.style.format(format_dict).hide_index()


test = df_Stars.groupby(["Contribution"])["Movies"]
# test.describe().style.format({"max":'${0:,.0f}'})
test.describe().style.format('{0:,.0f}')
# test.head(1)
# .style.format({'C': str.upper})

# adf.head().style.format({"col1": "{:,.0f}", "col2": "{:,.0f}"}) (per
# Out:
# <style  type="text/css" >
# </style><table id="T_a3daf7b2_0675_11eb_a226_482ae352cd8b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >Contribution</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3daf7b2_0675_11eb_a226_482ae352cd8blevel0_row0" class="row_heading level0 row0" >Actor</th>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col0" class="data row0 col0" >1,301</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col1" class="data row0 col1" >10</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col2" class="data row0 col2" >10</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col4" class="data row0 col4" >3</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col5" class="data row0 col5" >7</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col6" class="data row0 col6" >14</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow0_col7" class="data row0 col7" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_a3daf7b2_0675_11eb_a226_482ae352cd8blevel0_row1" class="row_heading level0 row1" >Director</th>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col0" class="data row1 col0" >350</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col1" class="data row1 col1" >9</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col2" class="data row1 col2" >6</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col4" class="data row1 col4" >5</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col5" class="data row1 col5" >7</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col6" class="data row1 col6" >11</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow1_col7" class="data row1 col7" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_a3daf7b2_0675_11eb_a226_482ae352cd8blevel0_row2" class="row_heading level0 row2" >Producer</th>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col0" class="data row2 col0" >361</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col1" class="data row2 col1" >12</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col2" class="data row2 col2" >10</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col3" class="data row2 col3" >1</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col4" class="data row2 col4" >6</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col5" class="data row2 col5" >9</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col6" class="data row2 col6" >15</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow2_col7" class="data row2 col7" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_a3daf7b2_0675_11eb_a226_482ae352cd8blevel0_row3" class="row_heading level0 row3" >Writer</th>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col0" class="data row3 col0" >260</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col1" class="data row3 col1" >6</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col2" class="data row3 col2" >3</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col3" class="data row3 col3" >1</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col4" class="data row3 col4" >3</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col5" class="data row3 col5" >5</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col6" class="data row3 col6" >7</td>
#                         <td id="T_a3daf7b2_0675_11eb_a226_482ae352cd8brow3_col7" class="data row3 col7" >21</td>
#             </tr>
#     </tbody></table>

# %%
#  test = df_Stars["Contribution"]

# format_dict = {'25%':'${0:,.0f}', '50%':'${0:,.0f}'}
# monthly_sales.style.format(format_dict).hide_index()


# test = df_Stars.groupby(["Contribution"])["Movies","Average"]
# test.describe().style.format({"max":'${0:,.0f}'})
desc = test.describe()
desc.to_clipboard()
# test.head(1)
# .style.format({'C': str.upper})

# adf.head().style.format({"col1": "{:,.0f}", "col2": "{:,.0f}"}) (per

# %%
df_contributions = df_Stars.pivot_table(index=['Contribution'], values=["Movies", "Average", "Domestic Box Office"], aggfunc={"Movies":['sum','count','mean','min','max','std'],"Average":['sum','count','mean','min','max','std'], "Domestic Box Office":['sum','count','mean','min','max','std']}, dropna=True).reset_index()
df_contributions
# Out:
#   Contribution Average                                                                    Domestic Box Office                                                                       Movies
#                  count          max          mean         min           std           sum               count           max          mean          min           std           sum   count   max       mean  min        std      sum
# 0        Actor  1301.0  745749349.0  6.703890e+07   4480970.0  7.101713e+07  8.721761e+10              1301.0  5.655231e+09  5.348912e+08   76293381.0  7.042125e+08  6.958935e+11  1301.0  83.0  10.368947  1.0  10.076664  13490.0
# 1     Director   350.0  439055794.0  8.016342e+07   9079862.0  6.877073e+07  2.805720e+10               350.0  4.542165e+09  5.493357e+08  153225613.0  4.746382e+08  1.922675e+11   350.0  36.0   8.714286  1.0   5.803227   3050.0
# 2     Producer   361.0  608581744.0  9.233655e+07   9490597.0  7.886593e+07  3.333350e+10               361.0  8.545426e+09  8.175191e+08  258889160.0  8.163674e+08  2.951244e+11   361.0  85.0  11.623269  1.0  10.111705   4196.0
# 3       Writer   260.0  333172112.0  1.100600e+08  18122908.0  6.524701e+07  2.861560e+10               260.0  3.175631e+09  5.409948e+08  214949076.0  4.433059e+08  1.406586e+11   260.0  21.0   5.515385  1.0   3.058590   1434.0

# %%
df_Stars_sample = df_Stars.head()

x = df_Stars_sample["Movies"]
y = df_Stars_sample["Average"]
z = df_Stars_sample["Domestic Box Office"]

# %%
import seaborn as sns 

sns.set_theme(style="white") 
# Load the example mpg dataset 
mpg = sns.load_dataset("mpg") 
# Plot miles per gallon against horsepower with other semantics 
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight", sizes=(40, 400), alpha=.5, palette="muted", height=6, data=mpg)

# %%
df_IMDB_MovieCatalog
df_Movie_Financials
df_StarPlayersWith_Tconst

# %%
df_StarPlayersWith_Tconst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20036 entries, 0 to 20035
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           20036 non-null  int64
#  1   Rank                 20036 non-null  int64
#  2   Name_IMDB            20036 non-null  object
#  3   Name                 20036 non-null  object
#  4   Domestic Box Office  20036 non-null  int64
#  5   Movies               20036 non-null  int64
#  6   Average              20036 non-null  int64
#  7   Link                 20036 non-null  object
#  8   Contribution         20036 non-null  object
#  9   BirthdayClean        20036 non-null  object
#  10  nameyear             20036 non-null  object
#  11  nconst               19867 non-null  object
#  12  tconst               19867 non-null  object
#  13  A_Player             20036 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 2.1+ MB

# %%
df_IMDB_MovieCatalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31060 entries, 0 to 31059
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      31060 non-null  int64
#  1   tconst          31060 non-null  object
#  2   primaryTitle    31060 non-null  object
#  3   startYear       31060 non-null  int64
#  4   runtimeMinutes  31060 non-null  int64
#  5   genres          31060 non-null  object
#  6   startYear_str   31060 non-null  int64
#  7   titleyear       31060 non-null  object
#  8   studio_BOM      4560 non-null   object
#  9   MPAA            2865 non-null   object
#  10  rd              4560 non-null   datetime64[ns]
#  11  StudioDesc      4057 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 2.8+ MB

# %%
df_Movie_Financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5540 entries, 0 to 5539
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5540 non-null   int64
#  1   tconst            5540 non-null   object
#  2   P_Cost            5540 non-null   float64
#  3   Dom_Gross         5540 non-null   int64
#  4   Frgn_Gross        5540 non-null   int64
#  5   WW_Gross          5540 non-null   int64
#  6   Domestic Opening  5540 non-null   int64
#  7   year              5540 non-null   int64
#  8   TicketPrice       5540 non-null   float64
#  9   EstInflation      5540 non-null   float64
#  10  Multiplier        5540 non-null   float64
#  11  adj_P_Cost        5540 non-null   float64
#  12  adj_Frgn_Gross    5540 non-null   float64
#  13  adj_WW_Gross      5540 non-null   float64
#  14  Profits           5540 non-null   float64
#  15  adj_Profits       5540 non-null   float64
#  16  ROI               5540 non-null   float64
# dtypes: float64(10), int64(6), object(1)
# memory usage: 735.9+ KB

# %%
df_StarPlayersWith_Tconst_Small = df_StarPlayersWith_Tconst[["Name","Contribution","tconst","A_Player"]]
.merge(df_IMDB_MovieCatalog[["Primarytitle","genres"]], on="tconst", how ="inner").
merge(df_Movie_Financials[["P_Cost","Dom_Gross","Frgn_Gross","WW_Gross","year","Profits","adj_Profits"
                          ,"adj_WW_Gross"]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns, numpy as np
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
plt.show()
