# %%
import numpy as np #linear algebra
import pandas as pd #data processing 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# Importing into dataframe
# df_Title_Basics = pd.read_csv("./Prj_Data/DownLoadedData_Imdb/title.basics (1).tsv.gz", delimiter='\t', encoding='ANSI')
df_Name_Basics = pd.read_csv("./Prj_Data/DownLoadedData_Imdb/name.basics (1).tsv.gz", delimiter='\t', encoding='ANSI')

# df_Generes_With_tconst = pd.read_excel("df_Generes_With_tconst.xlsx")
df_IMDB_MovieCatalog = pd.read_excel("df_IMDB_MovieCatalog.xlsx")
df_starsplayers_knownForMovie = pd.read_excel ('./Prj_Data/ImdbScrapingData/TheNumbers/output/starActorMovies_All.xlsx', sheet_name='Export')
df_starsplayers = pd.read_excel ('./Prj_Data/ImdbScrapingData/TheNumbers/input/StarEarningsv1_NoMacro.xlsx', sheet_name='Export')

# %%
#___________________________________Insert nconst into actor table________________________

# %%
df_starsplayers.info()
df_starsplayers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 3000 non-null   int64
#  1   Name                 3000 non-null   object
#  2   Domestic Box Office  3000 non-null   int64
#  3   Movies               3000 non-null   int64
#  4   Average              3000 non-null   int64
#  5   Link                 3000 non-null   object
#  6   Contribution         3000 non-null   object
#  7   BirthdayClean        2573 non-null   object
#  8   nameyear             2573 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 211.1+ KB
#    Rank                Name  Domestic Box Office  Movies    Average                                                            Link Contribution      BirthdayClean                nameyear
# ...

# %%
df_starsplayers_knownForMovie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ind_Org                 17364 non-null  int64
#  1   Actor                   17364 non-null  object
#  2   Born                    17364 non-null  object
#  3   ReleaseDate             17364 non-null  object
#  4   ReleaseYear             17364 non-null  int64
#  5   Title                   17364 non-null  object
#  6   Role                    17157 non-null  object
#  7   DomesticBoxOffice       17364 non-null  int64
#  8   InternationalBoxOffice  17211 non-null  float64
#  9   WorldwideBoxOffice      0 non-null      float64
#  10  ActorYear               17364 non-null  object
#  11  Contribution            17364 non-null  object
#  12  titleyear               17364 non-null  object
#  13  Column1                 0 non-null      float64
# ...

# %%
df_Name_Basics["nameyear"] = df_Name_Basics["primaryName"] + df_Name_Basics["birthYear"]
df_Name_Basics = df_Name_Basics[["nameyear","nconst","primaryName"]]

# %%
df_starsplayers_WithNconst = df_starsplayers.merge(df_Name_Basics, on="nameyear", how="left").drop_duplicates()

# %%
df_starsplayers_WithNconst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3004 entries, 0 to 3003
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 3004 non-null   int64
#  1   Name                 3004 non-null   object
#  2   Domestic Box Office  3004 non-null   int64
#  3   Movies               3004 non-null   int64
#  4   Average              3004 non-null   int64
#  5   Link                 3004 non-null   object
#  6   Contribution         3004 non-null   object
#  7   BirthdayClean        2577 non-null   object
#  8   nameyear             2577 non-null   object
#  9   nconst               1320 non-null   object
#  10  primaryName          1320 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 281.6+ KB

# %%
df_starsplayers_WithNconst.groupby(["nameyear", "Contribution"])["Name"].count().sort_values(ascending=False)
# Out:
# nameyear                         Contribution
# Jim Carter1948                   Actor           2
# Simon West1961                   Director        2
# Michelle Williams1980            Actor           2
# Kevin Smith1970                  Director        2
# will.i.am1975                    Actor           1
# Gary Ross1956                    Writer          1
#                                  Director        1
# Gary Oldman1958                  Actor           1
# Gary Lucchesi1958                Producer        1
# Gary Levinsohn1955               Producer        1
# Gary Goetzman Day                Producer        1
# Gary Foster1967                  Producer        1
# Gary Dauberman1970               Writer          1
# Gavin Hood1961                   Director        1
# Gary Barber1973                  Producer        1
# Garry Shandling2016              Actor           1
# Garry Marshall2016               Director        1
# ...

# %%
df_starsplayers_WithNconst.head()
# Out:
#    Rank                Name  Domestic Box Office  Movies    Average                                                            Link Contribution      BirthdayClean                nameyear     nconst         primaryName
# 0     1   Samuel L. Jackson           5655231264      64   88362989      https://www.the-numbers.com/person/670401-Samuel-L-Jackson        Actor  December 21, 1948   Samuel L. Jackson1948  nm0000168   Samuel L. Jackson
# 1     2  Robert Downey, Jr.           5474166329      43  127306194    https://www.the-numbers.com/person/41500401-Robert-Downey-Jr        Actor      April 4, 1965  Robert Downey, Jr.1965        NaN                 NaN
# 2     3           Tom Hanks           5021263837      51   98456154             https://www.the-numbers.com/person/650401-Tom-Hanks        Actor       July 9, 1956           Tom Hanks1956  nm0000158           Tom Hanks
# ...

# %%
df_starsplayers_WithNconst.to_excel("df_starsplayers.xlsx")

# %%
#________________________insert tconstinto KnownforMoviesTable_________________________________________

# %%
df_IMDB_MovieCatalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31060 entries, 0 to 31059
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      31060 non-null  int64
#  1   tconst          31060 non-null  object
#  2   primaryTitle    31060 non-null  object
#  3   startYear       31060 non-null  int64
#  4   runtimeMinutes  31060 non-null  int64
#  5   genres          31060 non-null  object
#  6   startYear_str   31060 non-null  int64
#  7   titleyear       31060 non-null  object
#  8   studio_BOM      4560 non-null   object
#  9   MPAA            2865 non-null   object
#  10  rd              4560 non-null   datetime64[ns]
#  11  StudioDesc      4057 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 2.8+ MB

# %%
df_starsplayers_knownForMovie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ind_Org                 17364 non-null  int64
#  1   Actor                   17364 non-null  object
#  2   Born                    17364 non-null  object
#  3   ReleaseDate             17364 non-null  object
#  4   ReleaseYear             17364 non-null  int64
#  5   Title                   17364 non-null  object
#  6   Role                    17157 non-null  object
#  7   DomesticBoxOffice       17364 non-null  int64
#  8   InternationalBoxOffice  17211 non-null  float64
#  9   WorldwideBoxOffice      0 non-null      float64
#  10  ActorYear               17364 non-null  object
#  11  Contribution            17364 non-null  object
#  12  titleyear               17364 non-null  object
#  13  Column1                 0 non-null      float64
# ...

# %%
df_starsplayers_knownForMovieWithTconst = df_starsplayers_knownForMovie.merge(df_IMDB_MovieCatalog_Small, on="titleyear", how="left").drop_duplicates()

# %%
df_starsplayers_knownForMovieWithTconst.to_excel("df_starsplayers_knownForMovies.xlsx")

# %%
df_Title_Episods[df_Title_Episods["tconst"]=="tt0077869"]
# df_Title_Episods[df_Title_Episods['primaryTitle'].str.contains('Lord of the Rings')]

# %%
df_Title_Basics['primaryTitle'].fillna("0", inplace=True)
df_Title_Basics[df_Title_Basics['primaryTitle'].str.contains('Lord of the Rings')]
