# %% [markdown]
# #THIS FILE WAS TO DEDUP AND ALIGN THE A PLAYER BIRTHDAYS FROM THE NUMBERS SCRAPPED DATA WTIH WITH THE IMDB DATA, FOR SOME THERE DIFFERENCES BEWTEEN FUNCTIONS, EX. TOM CRUISE HAD TWO DIFFERENT DAYS LISTED FOR HIS BIRTHDAY, NEEDED TO COLLAPSE AND THEN NEEDED TO ENSURE THAT THE DATA ALIGNED WITH THE DATES IN IMDB, NEED TO ADJUST MANUALLY

# %%
import numpy as np #linear algebra
import pandas as pd #data processing 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# Importing into dataframe
df_starsplayer_knowForMovie = pd.read_excel ('../zippedData/starActorMovies_All.xlsx', sheet_name='Export')

# %%
df_starsplayer_knowForMovie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17347 entries, 0 to 17346
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Ind_Org                 17347 non-null  int64
#  1   Actor                   17347 non-null  object
#  2   Born                    17347 non-null  object
#  3   ReleaseDate             17347 non-null  object
#  4   ReleaseYear             17347 non-null  int64
#  5   Title                   17347 non-null  object
#  6   Role                    17140 non-null  object
#  7   DomesticBoxOffice       17347 non-null  int64
#  8   InternationalBoxOffice  17194 non-null  float64
#  9   WorldwideBoxOffice      0 non-null      float64
#  10  ActorYear               17347 non-null  object
#  11  Contribution            17347 non-null  object
#  12  titleyear               17347 non-null  object
#  13  Column1                 0 non-null      float64
# ...

# %%
ActorBirtDates = df_starsplayer_knowForMovie[["Actor","Born","nameyear"]].drop_duplicates().fillna("0")

# %%
ActorBirtDates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2367 entries, 0 to 17337
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Actor     2367 non-null   object
#  1   Born      2367 non-null   object
#  2   nameyear  2367 non-null   object
# dtypes: object(3)
# memory usage: 74.0+ KB

# %%
ActorBirtDatesClean = ActorBirtDates.sort_values(by=["Actor","Born"]).drop_duplicates(subset='Actor', keep='first')

# %%
ActorBirtDatesClean.sort_values(by="Actor")
# Out:
#                              Actor                Born                                     nameyear
# 0                    Aaron Eckhart      March 12, 1968                  Aaron EckhartMarch 12, 1968
# 13                     Aaron Ryder   February 22, 1975                 Aaron RyderFebruary 22, 1975
# 20                    Aaron Sorkin        June 9, 1961                     Aaron SorkinJune 9, 1961
# 25            Aaron Taylor-Johnson       June 13, 1990            Aaron Taylor-JohnsonJune 13, 1990
# 33                       Aaron Yoo       June 21, 1982                       Aaron YooJune 21, 1982
# 39                       Abbey Lee       June 12, 1987                       Abbey LeeJune 12, 1987
# 43                       Abby Kohn   February 21, 1979                   Abby KohnFebruary 21, 1979
# 47                 Abigail Breslin      April 14, 1996                Abigail BreslinApril 14, 1996
# ...

# %%
ActorBirtDatesClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2272 entries, 0 to 17021
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Actor     2272 non-null   object
#  1   Born      2272 non-null   object
#  2   nameyear  2272 non-null   object
# dtypes: object(3)
# memory usage: 71.0+ KB

# %%
#USED TO Align Dates of Birth - Both actor spreadsheets via Vloopkup
ActorBirtDatesClean.to_excel("ActorBirthDatesClean.xlsx")

# %%
df_starsAct[df_starsAct["Name"]=="Tom Cruise"]
# Out:
#    Rank        Name  WorldwideBox Office  Movies    Average
# 10   11  Tom Cruise          10014535566      42  238441323

# %%
df_Title_Episods[df_Title_Episods["tconst"]=="tt0077869"]
# df_Title_Episods[df_Title_Episods['primaryTitle'].str.contains('Lord of the Rings')]
