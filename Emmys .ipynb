# %%
from bs4 import BeautifulSoup
import requests 
import re  
import pandas as pd

# %%
page = 'https://en.wikipedia.org/wiki/List_of_Primetime_Emmy_Award_winners'
response = requests.get(page, timeout=1)
firstsoup = BeautifulSoup(response.text, 'html.parser')
url = firstsoup.find_all(class_='wikitable', attrs={'a'} )
url
# Out:
# [<table class="wikitable">
#  <tbody><tr>
#  <th>Year
#  </th>
#  <th><a href="/wiki/Primetime_Emmy_Award_for_Outstanding_Comedy_Series" title="Primetime Emmy Award for Outstanding Comedy Series">Comedy</a>
#  </th>
#  <th><a href="/wiki/Primetime_Emmy_Award_for_Outstanding_Drama_Series" title="Primetime Emmy Award for Outstanding Drama Series">Drama</a>
#  </th>
#  <th><a href="/wiki/Primetime_Emmy_Award_for_Outstanding_Variety_Series" title="Primetime Emmy Award for Outstanding Variety Series">Variety</a>
#  </th>
#  <th><a href="/wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Comedy_Series" title="Primetime Emmy Award for Outstanding Lead Actor in a Comedy Series">Lead Comedy Actor</a>
#  </th>
#  <th><a href="/wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Drama_Series" title="Primetime Emmy Award for Outstanding Lead Actor in a Drama Series">Lead Drama Actor</a>
#  </th>
# ...

# %%
for urls in url:
    text = ''.join(url.findAll(text=True))
    data = text.strip()
    
data.splitlines()

s = if str().isnumeric == true
matched_indexes = []
i = 0
length = len(data)

while i < length:
    if s == data[i]:
        matched_indexes.append(i)
    i += 1

matched_indexes
# Out:
#   File "<ipython-input-178-22d8f66ee8d2>", line 7
#     s = if str().isnumeric == true
#          ^
# SyntaxError: invalid syntax

# %%
years = []
i = 0
for int in data: 
    years.append(data)
    i += 1
    
Titles2 = []
c = 0 

#for url in urls: 
#    Titles2.append(urls[c].find('a', class_="summary-title-link").attrs['href'])
#    c += 1
    
print(years)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-12dee05792aa> in <module>
#       2 i = 0
#       3 for int in data:
# ----> 4     years.append(data.find(len(int[i]) == 4))
#       5     i += 1
#       6
#
# TypeError: must be str, not bool
